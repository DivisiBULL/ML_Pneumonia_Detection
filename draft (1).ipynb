# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Main" data-toc-modified-id="Main-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Main</a></span><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Introduction</a></span><ul class="toc-item"><li><span><a href="#Dataset" data-toc-modified-id="Dataset-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Dataset</a></span></li><li><span><a href="#Modeling" data-toc-modified-id="Modeling-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Modeling</a></span></li></ul></li><li><span><a href="#Imports" data-toc-modified-id="Imports-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Imports</a></span></li><li><span><a href="#Visualizing-Data" data-toc-modified-id="Visualizing-Data-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Visualizing Data</a></span></li><li><span><a href="#Data-Preprocessing-&amp;-Augmentation" data-toc-modified-id="Data-Preprocessing-&amp;-Augmentation-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Data Preprocessing &amp; Augmentation</a></span></li><li><span><a href="#Modeling" data-toc-modified-id="Modeling-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Modeling</a></span><ul class="toc-item"><li><span><a href="#Baseline-Model" data-toc-modified-id="Baseline-Model-1.5.1"><span class="toc-item-num">1.5.1&nbsp;&nbsp;</span>Baseline Model</a></span></li><li><span><a href="#Weighted-Model" data-toc-modified-id="Weighted-Model-1.5.2"><span class="toc-item-num">1.5.2&nbsp;&nbsp;</span>Weighted Model</a></span></li><li><span><a href="#Models-with-different-optimizers" data-toc-modified-id="Models-with-different-optimizers-1.5.3"><span class="toc-item-num">1.5.3&nbsp;&nbsp;</span>Models with different optimizers</a></span><ul class="toc-item"><li><span><a href="#RMSprop" data-toc-modified-id="RMSprop-1.5.3.1"><span class="toc-item-num">1.5.3.1&nbsp;&nbsp;</span>RMSprop</a></span></li><li><span><a href="#SGD" data-toc-modified-id="SGD-1.5.3.2"><span class="toc-item-num">1.5.3.2&nbsp;&nbsp;</span>SGD</a></span></li></ul></li></ul></li><li><span><a href="#Transfer-Learning" data-toc-modified-id="Transfer-Learning-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Transfer Learning</a></span><ul class="toc-item"><li><span><a href="#VGG16" data-toc-modified-id="VGG16-1.6.1"><span class="toc-item-num">1.6.1&nbsp;&nbsp;</span>VGG16</a></span><ul class="toc-item"><li><span><a href="#Fine-Tuning" data-toc-modified-id="Fine-Tuning-1.6.1.1"><span class="toc-item-num">1.6.1.1&nbsp;&nbsp;</span>Fine Tuning</a></span></li><li><span><a href="#Eval-VGG16" data-toc-modified-id="Eval-VGG16-1.6.1.2"><span class="toc-item-num">1.6.1.2&nbsp;&nbsp;</span>Eval VGG16</a></span></li></ul></li><li><span><a href="#VGG19" data-toc-modified-id="VGG19-1.6.2"><span class="toc-item-num">1.6.2&nbsp;&nbsp;</span>VGG19</a></span></li><li><span><a href="#Xception" data-toc-modified-id="Xception-1.6.3"><span class="toc-item-num">1.6.3&nbsp;&nbsp;</span>Xception</a></span></li></ul></li><li><span><a href="#Evaluation" data-toc-modified-id="Evaluation-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Evaluation</a></span></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Conclusion</a></span></li><li><span><a href="#Future-Work" data-toc-modified-id="Future-Work-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>Future Work</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Main

# %% [markdown]
# ## Introduction
#
# **Disclaimer**
#
# **This project was completed for educational purposes only. Do not consider any of this as medical advice**
#
# My objective with this project was to be able to use X-rays from pediatric patients to be able to identify whether or not the patient has pneumonia. I accomplished this task using deep learning and transfer models
#
# My business case was to be able to quickly scan through a large amount of X-Ray images and be able to flag cases that were extremely likely to have Pneumonia to be able to more rapidly get them treatment. Given the limited data and limited time to work on this it was extremely unlikely to get a model that would be able to consistently outperform a doctor on diagnosis. This is only intended to be used as an aid for doctors to try and increase speed of diagnosis.
#
# As this was run on my personal work computer, some elements (such as number of epochs) have been reduced in some models to reduce time spent modeling. This can reduce model accuracy in some cases.

# %% [markdown]
# ### Dataset
# The data is not included in my github repository as it exceeds upload limits. To download the dataset you can visit [Kaggle](https://www.kaggle.com/datasets/paultimothymooney/chest-xray-pneumonia)
# Or for a larger version of the dataset visit [Mendeley](https://data.mendeley.com/datasets/rscbjbr9sj/3)
#
# If you want to run the notebook you will need to change the download paths to where your files are located (this is mentioned in the notebook where you need to change it)
#
# The dataset contains 5,863 X-Ray images (JPEG) that are split into 2 categories (Pneumonia/Normal), the dataset is highly unbalanced with more normal cases being represented. For each category the images are split into 3 folders (train, test, val) with Pneumonia/Normal cases appearing in all folders
# Chest X-ray images (anterior-posterior) were selected from retrospective cohorts of pediatric patients of one to five years old from Guangzhou Women and Children’s Medical Center, Guangzhou. All chest X-ray imaging was performed as part of patients’ routine clinical care.
# For the analysis of chest x-ray images, all chest radiographs were initially screened for quality control by removing all low quality or unreadable scans. The diagnoses for the images were then graded by two expert physicians before being cleared for training the AI system. In order to account for any grading errors, the evaluation set was also checked by a third expert.

# %% [markdown]
# ### Modeling
# As there was limited data my main focus was on transfer models. I did some baseline models and experimented with a few things but quickly moved onto testing three transfer models (VGG16, VGG19, and Xception). All of these models were created for the Imagenet classification competition. For more information visit this [link](https://dl.acm.org/doi/10.1145/3065386)

# %% [markdown]
# ## Imports

# %%
# Imports
# visualization 
from PIL import Image
import os
import matplotlib.pyplot as plt

# Model
from keras.models import Sequential
from keras.layers import Dense, Input, Conv2D, MaxPooling2D, Flatten
from keras.preprocessing.image import ImageDataGenerator

# DS genreal
import numpy as np
import tensorflow as tf
import keras

# Eval
from sklearn.metrics import classification_report

# %% [markdown]
# ## Visualizing Data

# %% [markdown]
# **Note:** If you are running this code yourself you will need to download the data from [kaggle](https://www.kaggle.com/datasets/paultimothymooney/chest-xray-pneumonia) and change all of the paths to your local download path

# %%
# Create a list containing the names of the files in the directory
# If running yourself change all of the paths to your local download path
temp_train_n = os.listdir('/Users/aiden.local/Documents/Flatiron/Course-Material/phase_4/project_phase_4/draft/Test_Data/archive/chest_xray/chest_xray/train/NORMAL')
temp_train_p = os.listdir('/Users/aiden.local/Documents/Flatiron/Course-Material/phase_4/project_phase_4/draft/Test_Data/archive/chest_xray/chest_xray/train/PNEUMONIA')
 
# Select only images from temp_train_n
train_imgs_n = [file for file in temp_train_n if file.endswith('.jpeg')]
train_imgs_p = [file for file in temp_train_p if file.endswith('.jpeg')]

# %%
# Path of training NORMAL and PNEUMONIA cases
# If running yourself change all of the paths to your local download path
path_train_n = '/Users/aiden.local/Documents/Flatiron/Course-Material/phase_4/project_phase_4/draft/Test_Data/archive/chest_xray/chest_xray/train/NORMAL/'
path_train_p = '/Users/aiden.local/Documents/Flatiron/Course-Material/phase_4/project_phase_4/draft/Test_Data/archive/chest_xray/chest_xray/train/PNEUMONIA/'

# %%
# Loop through and create a path to each individual NORMAL image
list_train_n = []
for img in train_imgs_n:
    list_train_n.append(path_train_n + img)

# Loop through and create a path to each individual PNEUMONIA image
list_train_p = []
for img in train_imgs_p:
    list_train_p.append(path_train_p + img)

# %%
# Visualize the first NORMAL case
norm_load = Image.open(list_train_n[0])
plt.imshow(norm_load, cmap='gray');

# %%
# Visualize the last NORMAL case
norm_load = Image.open(list_train_n[-1])
plt.imshow(norm_load, cmap='gray');

# %%
# Visualize the first PNEUMONIA case
norm_load = Image.open(list_train_p[0])
plt.imshow(norm_load, cmap='gray');

# %%
# Visualize the last PNEUMONIA case
norm_load = Image.open(list_train_p[-1])
plt.imshow(norm_load, cmap='gray');

# %% [markdown]
# Looking at the differences between the normal and pneumonia cases, the pneumonia cases seems to be "foggier" but if I was shown the imgs without knowing their labels it would be hard for me to guess for each img in the list. Let's see if our model can do better than me (not a doctor)

# %% [markdown]
# ## Data Preprocessing & Augmentation

# %% [markdown]
# The RGB channel values are in the [0, 255] range. This is not ideal for a neural network; in general you should seek to make your input values small. Here, you will standardize values to be in the [0, 1] range by using ImageDataGenerator(rescale = 1./255)
#
# The function [ImageDataGenerator](https://studymachinelearning.com/keras-imagedatagenerator-with-flow_from_directory/) class allows the users to perform image augmentation while training the model
#
# For more info on Data Augmentation visit the above link or this [tutorial](https://www.tensorflow.org/tutorials/images/data_augmentation) from TensorFlow

# %%
# Setting paths
# If running yourself change all of the paths to your local download path
train_path = '/Users/aiden.local/Documents/Flatiron/Course-Material/phase_4/project_phase_4/draft/Test_Data/archive/chest_xray/chest_xray/train/'
val_path = '/Users/aiden.local/Documents/Flatiron/Course-Material/phase_4/project_phase_4/draft/Test_Data/archive/chest_xray/chest_xray/val/'
test_path = '/Users/aiden.local/Documents/Flatiron/Course-Material/phase_4/project_phase_4/draft/Test_Data/archive/chest_xray/chest_xray/test/'

# %%
# Data augmentation

# Train augmentation
train_generator = ImageDataGenerator(
    rescale = 1./255, # rgb range to [0,1]
    # Several steps of augmentation 
    # (shearing, zooming and flipping)
    shear_range = 0.2,
    zoom_range = 0.2,
    horizontal_flip = True)

# Apply train_generator to train data
training_set = train_generator.flow_from_directory(
    train_path,
    # resize images to 64x64
    target_size = (64, 64),
    class_mode = 'binary')

# Test and val augmentation
# Scale normalization rgb [0, 255] range to [0,1]
test_generator = ImageDataGenerator(rescale = 1./255)  

# Apply test_generator to test data
test_set = test_generator.flow_from_directory(
    test_path,
    # resize images to 64x64
    target_size = (64, 64),
    class_mode = 'binary')
# Uses same generator as test
# Apply test_generator to val data
validation_set = test_generator.flow_from_directory(
    val_path,
    # resize images to 64x64
    target_size=(64, 64),
    class_mode='binary')
# Out:
# Found 5216 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.

# %%
# Found 5216 images belonging to 2 classes. - From training
# Found 16 images belonging to 2 classes. - From validation
# Found 624 images belonging to 2 classes. - From testing

# %% [markdown]
# **Note** The validation set from Kaggle is extremely small with only 16 images in total (from the 2 classes). I attempted to fix this by moving a selection of the images from the train directory to the val directory but could not get them to load properly. For the sake of time I chose to move on with the original data from Kaggle. This will make it difficult to gain meaningful results from the validation set analytics later on.
#
# You can visit this [link](https://data.mendeley.com/datasets/rscbjbr9sj/3) for a larger scale of this dataset that is not from Kaggle. But it has a different structure so other preprocessing steps would likely be necessary

# %%
# get unique values and counts
ar_unique, i = np.unique(training_set.classes, return_counts=True)
# display the returned array
print("Unique values:", ar_unique)
# display the counts
print("Counts:", i)

# 0 is number of imgs in train NORMAL
# 1 is number of imgs in train PNEUMONIA
# Out:
# Unique values: [0 1]
# Counts: [1341 3875]

# %% [markdown]
# Our dataset is highly unbalanced. We will be using label weights with our model. But there are other strategies like downsampling or upsampling the data. You can read more about these techniques [here](https://towardsdatascience.com/how-to-deal-with-imbalanced-data-in-python-f9b71aba53eb) (Medium members only link, you get access to 3 free posts a month)

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Baseline Model

# %% [markdown]
# Our baseline model is a relatively simple CNN that I will be using to judge model performance against more complex models

# %%
# Initialize model
model_baseline = Sequential()

# First hidden layer
model_baseline.add(Conv2D(32, (3, 3), 
                          activation="relu", 
                          input_shape=(64, 64, 3)))

# Second hidden layer
model_baseline.add(Conv2D(32, (3, 3), activation="relu"))

# Flatten
model_baseline.add(Flatten())

# Output layer
model_baseline.add(Dense(1, activation = 'sigmoid'))

# Compile the model
model_baseline.compile(optimizer = 'adam',
                       loss = 'binary_crossentropy',
                       metrics = ['accuracy'])

# %%
# Fit model on training set
# Save to history in order to more easily visualize
history_base = model_baseline.fit(
    training_set, 
    epochs = 10, 
    validation_data = validation_set)
# Out:
# Epoch 1/10
# 163/163 [==============================] - 108s 665ms/step - loss: 0.4099 - accuracy: 0.8253 - val_loss: 0.6778 - val_accuracy: 0.6875
# Epoch 2/10
# 163/163 [==============================] - 109s 666ms/step - loss: 0.2490 - accuracy: 0.8961 - val_loss: 0.4214 - val_accuracy: 0.8750
# Epoch 3/10
# 163/163 [==============================] - 110s 675ms/step - loss: 0.2247 - accuracy: 0.9095 - val_loss: 0.4974 - val_accuracy: 0.8750
# Epoch 4/10
# 163/163 [==============================] - 109s 670ms/step - loss: 0.2088 - accuracy: 0.9170 - val_loss: 0.3391 - val_accuracy: 0.8750
# Epoch 5/10
# 163/163 [==============================] - 109s 669ms/step - loss: 0.2064 - accuracy: 0.9156 - val_loss: 0.7368 - val_accuracy: 0.6250
# Epoch 6/10
# 163/163 [==============================] - 108s 664ms/step - loss: 0.1782 - accuracy: 0.9279 - val_loss: 0.2854 - val_accuracy: 0.8750
# Epoch 7/10
# 163/163 [==============================] - 107s 657ms/step - loss: 0.1685 - accuracy: 0.9346 - val_loss: 0.4708 - val_accuracy: 0.8125
# Epoch 8/10
# 163/163 [==============================] - 109s 666ms/step - loss: 0.1605 - accuracy: 0.9352 - val_loss: 0.2863 - val_accuracy: 0.8750
# Epoch 9/10
# 163/163 [==============================] - 109s 670ms/step - loss: 0.1642 - accuracy: 0.9381 - val_loss: 0.2606 - val_accuracy: 0.8125
# Epoch 10/10
# 163/163 [==============================] - 108s 660ms/step - loss: 0.1635 - accuracy: 0.9394 - val_loss: 0.3170 - val_accuracy: 0.8750

# %% [markdown]
# ### Weighted Model

# %% [markdown]
# Our model architecture is actually the same as our baseline model we just impose weights to the labels as our data is highly unbalanced.

# %%
# Initialize model
model_weighted = Sequential()

# First hidden layer
model_weighted.add(Conv2D(32, (3, 3), 
                          activation="relu", 
                          input_shape=(64, 64, 3)))

# Second hidden layer
model_weighted.add(Conv2D(32, (3, 3), activation="relu"))

# Flatten
model_weighted.add(Flatten())

# Output layer
model_weighted.add(Dense(1, activation = 'sigmoid'))

# Compile the model
model_weighted.compile(optimizer = 'adam',
                       loss = 'binary_crossentropy',
                       metrics = ['accuracy'])

# %%
# Fit model on training set
history_weighted = model_weighted.fit(
    training_set, 
    epochs = 10,
    validation_data = validation_set,
    # model weight. Calculated from level of unbalance in data
    class_weight={0:2.8 , 1:1})
# Out:
# Epoch 1/10
# 163/163 [==============================] - 108s 663ms/step - loss: 0.7991 - accuracy: 0.7099 - val_loss: 0.3289 - val_accuracy: 0.9375
# Epoch 2/10
# 163/163 [==============================] - 108s 664ms/step - loss: 0.4544 - accuracy: 0.8715 - val_loss: 0.4330 - val_accuracy: 0.7500
# Epoch 3/10
# 163/163 [==============================] - 107s 658ms/step - loss: 0.4240 - accuracy: 0.8798 - val_loss: 0.3242 - val_accuracy: 0.8125
# Epoch 4/10
# 163/163 [==============================] - 109s 668ms/step - loss: 0.3569 - accuracy: 0.9015 - val_loss: 0.2624 - val_accuracy: 0.9375
# Epoch 5/10
# 163/163 [==============================] - 108s 664ms/step - loss: 0.3224 - accuracy: 0.9130 - val_loss: 0.2905 - val_accuracy: 0.8125
# Epoch 6/10
# 163/163 [==============================] - 107s 658ms/step - loss: 0.3365 - accuracy: 0.9055 - val_loss: 0.2847 - val_accuracy: 0.8750
# Epoch 7/10
# 163/163 [==============================] - 109s 668ms/step - loss: 0.2985 - accuracy: 0.9201 - val_loss: 0.2415 - val_accuracy: 0.8750
# Epoch 8/10
# 163/163 [==============================] - 109s 668ms/step - loss: 0.3017 - accuracy: 0.9133 - val_loss: 0.3791 - val_accuracy: 0.8125
# Epoch 9/10
# 163/163 [==============================] - 108s 662ms/step - loss: 0.2656 - accuracy: 0.9270 - val_loss: 0.2343 - val_accuracy: 0.8750
# Epoch 10/10
# 163/163 [==============================] - 107s 658ms/step - loss: 0.2715 - accuracy: 0.9271 - val_loss: 0.2064 - val_accuracy: 1.0000

# %%
# Accuracy graphing
plt.plot(history_weighted.history['accuracy'])
plt.plot(history_weighted.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training set', 'Validation set'], loc='upper left')
plt.show()

# %%
# Loss graphing
plt.plot(history_weighted.history['val_loss'])
plt.plot(history_weighted.history['loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training set', 'Validation set'], loc='upper left')
plt.show()

# %% [markdown]
# ### Models with different optimizers

# %% [markdown]
# Adam is currently one of the most popular and powerful optimizers. Here we will quickly try a few others with the same architecture as our previous models to act as a baseline.
#
# For more details on these optimizers check out the [documentation](https://keras.io/api/optimizers/)

# %% [markdown]
# #### RMSprop

# %%
# Initialize model
model_rmsprop = Sequential()

# First hidden layer
model_rmsprop.add(Conv2D(32, (3, 3), 
                         activation="relu", 
                         input_shape=(64, 64, 3)))

# Second hidden layer
model_rmsprop.add(Conv2D(32, (3, 3), activation="relu"))

# Flatten
model_rmsprop.add(Flatten())

# Output layer
model_rmsprop.add(Dense(1, activation = 'sigmoid'))

# %%
# Compile the model with RMSprop optimizer
model_rmsprop.compile(optimizer = 'RMSprop',
                       loss = 'binary_crossentropy',
                       metrics = ['accuracy'])

# Fit the model
history_rmsprop = model_rmsprop.fit(
    training_set, 
    epochs = 10,
    validation_data = validation_set,
    class_weight={0:2.8 , 1:1} # model weight 
    )
# Out:
# Epoch 1/10
# 163/163 [==============================] - 110s 675ms/step - loss: 0.9030 - accuracy: 0.6887 - val_loss: 0.3599 - val_accuracy: 0.8125
# Epoch 2/10
# 163/163 [==============================] - 109s 667ms/step - loss: 0.5310 - accuracy: 0.8524 - val_loss: 0.3885 - val_accuracy: 0.8125
# Epoch 3/10
# 163/163 [==============================] - 107s 659ms/step - loss: 0.4636 - accuracy: 0.8811 - val_loss: 1.0545 - val_accuracy: 0.6250
# Epoch 4/10
# 163/163 [==============================] - 108s 661ms/step - loss: 0.3679 - accuracy: 0.9045 - val_loss: 0.4096 - val_accuracy: 0.8125
# Epoch 5/10
# 163/163 [==============================] - 108s 660ms/step - loss: 0.3478 - accuracy: 0.9080 - val_loss: 0.3568 - val_accuracy: 0.8125
# Epoch 6/10
# 163/163 [==============================] - 107s 659ms/step - loss: 0.3694 - accuracy: 0.9072 - val_loss: 0.4567 - val_accuracy: 0.7500
# Epoch 7/10
# 163/163 [==============================] - 108s 662ms/step - loss: 0.2920 - accuracy: 0.9185 - val_loss: 0.3231 - val_accuracy: 0.8750
# Epoch 8/10
# 163/163 [==============================] - 108s 660ms/step - loss: 0.3319 - accuracy: 0.9178 - val_loss: 0.2143 - val_accuracy: 0.9375
# Epoch 9/10
# 163/163 [==============================] - 107s 658ms/step - loss: 0.2912 - accuracy: 0.9243 - val_loss: 0.4525 - val_accuracy: 0.7500
# Epoch 10/10
# 163/163 [==============================] - 108s 660ms/step - loss: 0.2844 - accuracy: 0.9262 - val_loss: 0.2029 - val_accuracy: 0.9375

# %% [markdown]
# #### SGD

# %%
# Initialize model
model_sgd = Sequential()

# First hidden layer
model_sgd.add(Conv2D(32, (3, 3), 
                     activation="relu", 
                     input_shape=(64, 64, 3)))

# Second hidden layer
model_sgd.add(Conv2D(32, (3, 3), activation="relu"))

# Flatten
model_sgd.add(Flatten())

# Output layer
model_sgd.add(Dense(1, activation = 'sigmoid'))

# %%
# Compile the model with SGD optimizer
model_sgd.compile(optimizer = 'SGD',
                       loss = 'binary_crossentropy',
                       metrics = ['accuracy'])

# Fit the model
history_sgd = model_sgd.fit(
    training_set, 
    epochs = 25,
    validation_data = validation_set,
    class_weight={0:2.8 , 1:1} # model weight 
    )
# Out:
# Epoch 1/25
# 163/163 [==============================] - 109s 666ms/step - loss: 0.8178 - accuracy: 0.6946 - val_loss: 0.8749 - val_accuracy: 0.5000
# Epoch 2/25
# 163/163 [==============================] - 107s 659ms/step - loss: 0.5829 - accuracy: 0.8225 - val_loss: 0.5414 - val_accuracy: 0.8125
# Epoch 3/25
# 163/163 [==============================] - 109s 666ms/step - loss: 0.4682 - accuracy: 0.8587 - val_loss: 0.5493 - val_accuracy: 0.8125
# Epoch 4/25
# 163/163 [==============================] - 107s 658ms/step - loss: 0.4659 - accuracy: 0.8658 - val_loss: 0.5583 - val_accuracy: 0.8750
# Epoch 5/25
# 163/163 [==============================] - 108s 662ms/step - loss: 0.4174 - accuracy: 0.8831 - val_loss: 0.5363 - val_accuracy: 0.8750
# Epoch 6/25
# 163/163 [==============================] - 110s 674ms/step - loss: 0.4388 - accuracy: 0.8781 - val_loss: 0.6611 - val_accuracy: 0.6875
# Epoch 7/25
# 163/163 [==============================] - 109s 671ms/step - loss: 0.4080 - accuracy: 0.8808 - val_loss: 0.5542 - val_accuracy: 0.8750
# Epoch 8/25
# 163/163 [==============================] - 108s 664ms/step - loss: 0.3899 - accuracy: 0.8888 - val_loss: 0.6141 - val_accuracy: 0.6875
# Epoch 9/25
# 163/163 [==============================] - 109s 668ms/step - loss: 0.3717 - accuracy: 0.8972 - val_loss: 0.5725 - val_accuracy: 0.6875
# Epoch 10/25
# 163/163 [==============================] - 110s 674ms/step - loss: 0.3580 - accuracy: 0.8978 - val_loss: 0.6037 - val_accuracy: 0.7500
# Epoch 11/25
# 163/163 [==============================] - 110s 676ms/step - loss: 0.3688 - accuracy: 0.9015 - val_loss: 0.5414 - val_accuracy: 0.8125
# Epoch 12/25
# 163/163 [==============================] - 109s 669ms/step - loss: 0.3385 - accuracy: 0.9093 - val_loss: 0.5859 - val_accuracy: 0.6875
# Epoch 13/25
# 163/163 [==============================] - 109s 672ms/step - loss: 0.3474 - accuracy: 0.9051 - val_loss: 0.7489 - val_accuracy: 0.5625
# Epoch 14/25
# 163/163 [==============================] - 110s 674ms/step - loss: 0.3273 - accuracy: 0.9103 - val_loss: 0.4969 - val_accuracy: 0.8125
# Epoch 15/25
# 163/163 [==============================] - 110s 673ms/step - loss: 0.3157 - accuracy: 0.9160 - val_loss: 0.4989 - val_accuracy: 0.8125
# Epoch 16/25
# 163/163 [==============================] - 109s 669ms/step - loss: 0.3150 - accuracy: 0.9114 - val_loss: 0.5076 - val_accuracy: 0.8125
# Epoch 17/25
# 163/163 [==============================] - 109s 671ms/step - loss: 0.3251 - accuracy: 0.9087 - val_loss: 0.4729 - val_accuracy: 0.8125
# Epoch 18/25
# 163/163 [==============================] - 110s 676ms/step - loss: 0.3075 - accuracy: 0.9124 - val_loss: 0.4836 - val_accuracy: 0.8125
# Epoch 19/25
# 163/163 [==============================] - 108s 664ms/step - loss: 0.3079 - accuracy: 0.9172 - val_loss: 0.4516 - val_accuracy: 0.8125
# Epoch 20/25
# 163/163 [==============================] - 108s 665ms/step - loss: 0.2929 - accuracy: 0.9229 - val_loss: 0.4405 - val_accuracy: 0.8750
# Epoch 21/25
# 163/163 [==============================] - 109s 670ms/step - loss: 0.2918 - accuracy: 0.9191 - val_loss: 0.4596 - val_accuracy: 0.8125
# Epoch 22/25
# 163/163 [==============================] - 108s 665ms/step - loss: 0.2917 - accuracy: 0.9216 - val_loss: 0.4278 - val_accuracy: 0.8125
# Epoch 23/25
# 163/163 [==============================] - 109s 669ms/step - loss: 0.2853 - accuracy: 0.9243 - val_loss: 0.4507 - val_accuracy: 0.8125
# Epoch 24/25
# 163/163 [==============================] - 109s 669ms/step - loss: 0.2949 - accuracy: 0.9225 - val_loss: 0.4577 - val_accuracy: 0.7500
# Epoch 25/25
# 163/163 [==============================] - 109s 669ms/step - loss: 0.2974 - accuracy: 0.9210 - val_loss: 0.3967 - val_accuracy: 0.8750

# %% [markdown]
# The optimizer Adam in this case performs the best. To be more thorough it would be better to test different optimizers with the upcoming transfer models but I am going to skip this for the sake of resources and time. Adam is currently one of the most powerful optimizers so it would likely be the case it outperforms on upcoming models as well.

# %% [markdown]
# ## Transfer Learning

# %% [markdown]
# Transfer learning can be an essential tool when training a CNN with limited data. It takes a model that was trained on a different but much larger data set and tries to apply parts of it in a new use case. I will be testing 3 different transfer models for this case (VGG16, VGG19, and Xception). With weights coming from the imagenet competition
#
# For more information on transfer learning visit the [Keras Guide](https://keras.io/guides/transfer_learning/)

# %% [markdown]
# ### VGG16

# %%
# Set up the base transfer model
transfer_model_vgg16 = keras.applications.VGG16(
    weights='imagenet',  # Load weights pre-trained on ImageNet.
    input_shape=(64, 64, 3),
    include_top=False)  # Do not include the ImageNet classifier at the top.

# %%
# Freeze the transfer model
transfer_model_vgg16.trainable = False

# %%
# Create a new model on top of transfer model
# Initialize model
model_vgg16 = Sequential()
# Add transfer learning model as a layer
model_vgg16.add(transfer_model_vgg16)
# Flatten
model_vgg16.add(Flatten())
# Add dense layer
model_vgg16.add(Dense(20, activation = 'relu'))
# Add dense layer
model_vgg16.add(Dense(1, activation = 'sigmoid'))

# %%
# Preview the model structure/parameters
model_vgg16.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Functional)           (None, 2, 2, 512)         14714688
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 20)                40980
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 14,755,689
# Trainable params: 41,001
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# Compile the model
model_vgg16.compile(
    optimizer = 'adam',
    loss = 'binary_crossentropy',
    metrics = ['accuracy'])

# %%
# fit model 
history_vgg16 = model_vgg16.fit(
    training_set,
    epochs = 20,
    validation_data = validation_set,
    class_weight={0:2.8 , 1:1} # model weight
    )
# Out:
# Epoch 1/20
# 163/163 [==============================] - 128s 785ms/step - loss: 0.4665 - accuracy: 0.8721 - val_loss: 0.2338 - val_accuracy: 0.9375
# Epoch 2/20
# 163/163 [==============================] - 127s 780ms/step - loss: 0.3301 - accuracy: 0.9072 - val_loss: 0.2289 - val_accuracy: 0.9375
# Epoch 3/20
# 163/163 [==============================] - 126s 772ms/step - loss: 0.2984 - accuracy: 0.9197 - val_loss: 0.2339 - val_accuracy: 0.9375
# Epoch 4/20
# 163/163 [==============================] - 127s 778ms/step - loss: 0.2741 - accuracy: 0.9277 - val_loss: 0.2496 - val_accuracy: 0.9375
# Epoch 5/20
# 163/163 [==============================] - 127s 782ms/step - loss: 0.2505 - accuracy: 0.9344 - val_loss: 0.2390 - val_accuracy: 0.8750
# Epoch 6/20
# 163/163 [==============================] - 127s 777ms/step - loss: 0.2576 - accuracy: 0.9302 - val_loss: 0.2342 - val_accuracy: 0.9375
# Epoch 7/20
# 163/163 [==============================] - 126s 775ms/step - loss: 0.2462 - accuracy: 0.9346 - val_loss: 0.2496 - val_accuracy: 0.8750
# Epoch 8/20
# 163/163 [==============================] - 128s 784ms/step - loss: 0.2498 - accuracy: 0.9331 - val_loss: 0.2561 - val_accuracy: 0.8750
# Epoch 9/20
# 163/163 [==============================] - 127s 781ms/step - loss: 0.2256 - accuracy: 0.9406 - val_loss: 0.2337 - val_accuracy: 0.8750
# Epoch 10/20
# 163/163 [==============================] - 128s 786ms/step - loss: 0.2255 - accuracy: 0.9392 - val_loss: 0.2088 - val_accuracy: 0.9375
# Epoch 11/20
# 163/163 [==============================] - 127s 777ms/step - loss: 0.2438 - accuracy: 0.9362 - val_loss: 0.3281 - val_accuracy: 0.8750
# Epoch 12/20
# 163/163 [==============================] - 127s 778ms/step - loss: 0.2282 - accuracy: 0.9396 - val_loss: 0.2062 - val_accuracy: 0.8750
# Epoch 13/20
# 163/163 [==============================] - 127s 779ms/step - loss: 0.2242 - accuracy: 0.9436 - val_loss: 0.2205 - val_accuracy: 0.8750
# Epoch 14/20
# 163/163 [==============================] - 126s 774ms/step - loss: 0.2241 - accuracy: 0.9410 - val_loss: 0.2240 - val_accuracy: 0.8750
# Epoch 15/20
# 163/163 [==============================] - 127s 779ms/step - loss: 0.2300 - accuracy: 0.9387 - val_loss: 0.2621 - val_accuracy: 0.8750
# Epoch 16/20
# 163/163 [==============================] - 127s 777ms/step - loss: 0.2174 - accuracy: 0.9438 - val_loss: 0.2077 - val_accuracy: 0.8750
# Epoch 17/20
# 163/163 [==============================] - 128s 784ms/step - loss: 0.2251 - accuracy: 0.9396 - val_loss: 0.2745 - val_accuracy: 0.8125
# Epoch 18/20
# 163/163 [==============================] - 126s 774ms/step - loss: 0.2117 - accuracy: 0.9434 - val_loss: 0.2648 - val_accuracy: 0.8125
# Epoch 19/20
# 163/163 [==============================] - 127s 776ms/step - loss: 0.2106 - accuracy: 0.9431 - val_loss: 0.2508 - val_accuracy: 0.8750
# Epoch 20/20
# 163/163 [==============================] - 126s 775ms/step - loss: 0.1974 - accuracy: 0.9461 - val_loss: 0.2550 - val_accuracy: 0.8750

# %% [markdown]
# #### Fine Tuning

# %% [markdown]
# "A last, optional step, is fine-tuning, which consists of unfreezing the entire model you obtained above (or part of it), and re-training it on the new data with a very low learning rate. This can potentially achieve meaningful improvements, by incrementally adapting the pretrained features to the new data." - From the Keras guide below
#
# For more information on fine tuning transfer models visit the [Keras Guide](https://keras.io/guides/transfer_learning/)

# %%
# Unfreeze the base model
transfer_model_vgg16.trainable = True

# It's important to recompile your model after you make any changes
# to the `trainable` attribute of any inner layer, so that your changes
# are take into account
model_vgg16.compile(
    optimizer=keras.optimizers.Adam(1e-5), # low learning rate
    loss=keras.losses.BinaryCrossentropy(from_logits=True),
    metrics=[keras.metrics.BinaryAccuracy()])

# Train end-to-end. Be careful to stop before you overfit!
history_vgg16_tuned = model_vgg16.fit(
    training_set, 
    epochs = 3, # Low num of epochs to reduce chance of overfiting
    validation_data=validation_set)
# Out:
# Epoch 1/3
# 163/163 [==============================] - 332s 2s/step - loss: 0.4421 - binary_accuracy: 0.9321 - val_loss: 0.6911 - val_binary_accuracy: 0.6875
# Epoch 2/3
# 163/163 [==============================] - 331s 2s/step - loss: 0.4368 - binary_accuracy: 0.9438 - val_loss: 0.6185 - val_binary_accuracy: 0.8125
# Epoch 3/3
# 163/163 [==============================] - 330s 2s/step - loss: 0.4358 - binary_accuracy: 0.9446 - val_loss: 0.5774 - val_binary_accuracy: 0.8750

# %% [markdown]
# Validating against test data should only ever be done once when the best performing model has been selected to avoid data leakage. In this case the VGG16 model performs the best so I will be performing the validation here

# %% [markdown]
# #### Eval VGG16

# %%
# Make predictions on test data
predictions = model_vgg16.predict(test_set)

# %%
# Get most likely class from prediction
# A different way of doing:
# predicted_classes = np.argmax(predictions, axis=1)
# Was running into issues with argmax though
predicted_classes = []
for prediction in predictions:
    if prediction >= 0.8: # High cut off num to increase precision for 1
        predicted_classes.append(1)
    elif prediction < 0.8:
        predicted_classes.append(0)

# %%
# Set true classes and class labels
true_classes = test_set.classes
class_labels = list(test_set.class_indices.keys())

# %%
# Create classification report
report = classification_report(true_classes, 
                               predicted_classes, 
                               target_names=class_labels)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.40      0.39      0.39       234
#    PNEUMONIA       0.64      0.64      0.64       390
#
#     accuracy                           0.55       624
#    macro avg       0.52      0.52      0.52       624
# weighted avg       0.55      0.55      0.55       624

# %% [markdown]
# I use two ways of evaluating the model performance to illustrate that in some cases when not trying to achieve as high of precision you can get the base accuracy higher. In my business case precision for the 1 class label was more important

# %%
# Other ways of validating
test_acc = model_vgg16.evaluate(test_set)
print('The testing accuracy is :', test_acc[1]*100, '%')
# Out:
# 20/20 [==============================] - 13s 633ms/step - loss: 0.5012 - binary_accuracy: 0.9135
# The testing accuracy is : 91.34615659713745 %

# %% [markdown]
# ### VGG19

# %%
# Set up the base transfer model
transfer_model_vgg19 = keras.applications.VGG19(
    weights='imagenet',  # Load weights pre-trained on ImageNet.
    input_shape=(150, 150, 3),
    include_top=False)  # Do not include the ImageNet classifier at the top.

# %%
# Preview summary
transfer_model_vgg19.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 150, 150, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 150, 150, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 150, 150, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 75, 75, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 75, 75, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 75, 75, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 37, 37, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 37, 37, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 37, 37, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 18, 18, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 18, 18, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 9, 9, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Free the transfer model
transfer_model_vgg19.trainable = False

# %%
# Create a new model on top of transfer model
inputs = keras.Input(shape=(150, 150, 3))
#  transfer_model is running in inference mode by passing `training=False`. 
x = transfer_model_vgg19(inputs, training=False)
# Convert features of shape `transfer_model.output_shape[1:]` to vectors
x = keras.layers.GlobalAveragePooling2D()(x)
# A Dense classifier with a single unit (binary classification)
outputs = keras.layers.Dense(1)(x)
model_vgg19 = keras.Model(inputs, outputs)

# %%
# Compile the model
model_vgg19.compile(
    optimizer = 'adam',
    loss = 'binary_crossentropy',
    metrics = ['accuracy'])

# %%
# fit model 
history_vgg19 = model_vgg19.fit(
    training_set, 
    steps_per_epoch = 163,
    epochs = 15,
    validation_data = validation_set,
    class_weight={0:2.8 , 1:1})
# Out:
# Epoch 1/15
# 163/163 [==============================] - 134s 820ms/step - loss: 11.4593 - accuracy: 0.2571 - val_loss: 7.7125 - val_accuracy: 0.5000
# Epoch 2/15
# 163/163 [==============================] - 132s 811ms/step - loss: 11.4593 - accuracy: 0.2571 - val_loss: 7.7125 - val_accuracy: 0.5000
# Epoch 3/15
# 163/163 [==============================] - 133s 814ms/step - loss: 11.4593 - accuracy: 0.2571 - val_loss: 7.7125 - val_accuracy: 0.5000
# Epoch 4/15
# 163/163 [==============================] - 131s 807ms/step - loss: 11.4593 - accuracy: 0.2571 - val_loss: 7.7125 - val_accuracy: 0.5000
# Epoch 5/15
# 163/163 [==============================] - 132s 810ms/step - loss: 11.4593 - accuracy: 0.2571 - val_loss: 7.7125 - val_accuracy: 0.5000
# Epoch 6/15
# 163/163 [==============================] - 133s 815ms/step - loss: 11.4593 - accuracy: 0.2571 - val_loss: 7.7125 - val_accuracy: 0.5000
# Epoch 7/15
# 163/163 [==============================] - 133s 815ms/step - loss: 11.4593 - accuracy: 0.2571 - val_loss: 7.7125 - val_accuracy: 0.5000
# Epoch 8/15
# 163/163 [==============================] - 133s 817ms/step - loss: 11.4593 - accuracy: 0.2571 - val_loss: 7.7125 - val_accuracy: 0.5000
# Epoch 9/15
# 163/163 [==============================] - 133s 819ms/step - loss: 11.4593 - accuracy: 0.2571 - val_loss: 7.7125 - val_accuracy: 0.5000
# Epoch 10/15
# 163/163 [==============================] - 131s 806ms/step - loss: 11.4593 - accuracy: 0.2571 - val_loss: 7.7125 - val_accuracy: 0.5000
# Epoch 11/15
# 163/163 [==============================] - 132s 808ms/step - loss: 11.4593 - accuracy: 0.2571 - val_loss: 7.7125 - val_accuracy: 0.5000
# Epoch 12/15
# 163/163 [==============================] - 132s 810ms/step - loss: 11.4593 - accuracy: 0.2571 - val_loss: 7.7125 - val_accuracy: 0.5000
# Epoch 13/15
# 163/163 [==============================] - 132s 811ms/step - loss: 11.4593 - accuracy: 0.2571 - val_loss: 7.7125 - val_accuracy: 0.5000
# Epoch 14/15
# 163/163 [==============================] - 132s 811ms/step - loss: 11.4593 - accuracy: 0.2571 - val_loss: 7.7125 - val_accuracy: 0.5000
# Epoch 15/15
# 163/163 [==============================] - 134s 819ms/step - loss: 11.4593 - accuracy: 0.2571 - val_loss: 7.7125 - val_accuracy: 0.5000

# %% [markdown]
# ### Xception

# %%
# Transfer Model Xception
tm_Xception = keras.applications.Xception(
    weights='imagenet',  # Load weights pre-trained on ImageNet.
    input_shape=(150, 150, 3),
    include_top=False)  # Do not include the ImageNet classifier at the top.

# %%
# Freeze the transfer model
tm_Xception.trainable = False

# %%
inputs = keras.Input(shape=(150, 150, 3))
#  transfer_model is running in inference mode by passing `training=False`. 
x = tm_Xception(inputs, training=False)
# Convert features of shape `transfer_model.output_shape[1:]` to vectors
x = keras.layers.GlobalAveragePooling2D()(x)
# A Dense classifier with a single unit (binary classification)
outputs = keras.layers.Dense(1)(x)
model_Xception = keras.Model(inputs, outputs)

# %%
# Compile the model
model_Xception.compile(
    optimizer = 'adam',
    loss = 'binary_crossentropy',
    metrics = ['accuracy'])

# %%
# Fit the model
history_Xception = model_Xception.fit(
    training_set, 
    steps_per_epoch = 163,
    epochs = 15,
    validation_data = validation_set,
    class_weight={0:2.8 , 1:1})
# Out:
# Epoch 1/15
# 163/163 [==============================] - 113s 693ms/step - loss: 1.3471 - accuracy: 0.6885 - val_loss: 0.3555 - val_accuracy: 0.7500
# Epoch 2/15
# 163/163 [==============================] - 110s 678ms/step - loss: 0.9506 - accuracy: 0.8156 - val_loss: 0.3019 - val_accuracy: 0.9375
# Epoch 3/15
# 163/163 [==============================] - 112s 685ms/step - loss: 0.7296 - accuracy: 0.8424 - val_loss: 0.4873 - val_accuracy: 0.8125
# Epoch 4/15
# 163/163 [==============================] - 111s 680ms/step - loss: 1.1918 - accuracy: 0.7975 - val_loss: 0.4783 - val_accuracy: 0.6875
# Epoch 5/15
# 163/163 [==============================] - 111s 684ms/step - loss: 3.5683 - accuracy: 0.7786 - val_loss: 2.3282 - val_accuracy: 0.6875
# Epoch 6/15
# 163/163 [==============================] - 112s 685ms/step - loss: 3.4343 - accuracy: 0.7013 - val_loss: 2.0819 - val_accuracy: 0.7500
# Epoch 7/15
# 163/163 [==============================] - 110s 675ms/step - loss: 2.0238 - accuracy: 0.7719 - val_loss: 2.1694 - val_accuracy: 0.8125
# Epoch 8/15
# 163/163 [==============================] - 110s 677ms/step - loss: 1.8715 - accuracy: 0.7719 - val_loss: 1.9879 - val_accuracy: 0.8125
# Epoch 9/15
# 163/163 [==============================] - 110s 678ms/step - loss: 1.8470 - accuracy: 0.8338 - val_loss: 0.4017 - val_accuracy: 0.7500
# Epoch 10/15
# 163/163 [==============================] - 111s 680ms/step - loss: 2.0825 - accuracy: 0.8518 - val_loss: 1.2816 - val_accuracy: 0.8125
# Epoch 11/15
# 163/163 [==============================] - 110s 674ms/step - loss: 1.6619 - accuracy: 0.8470 - val_loss: 1.2865 - val_accuracy: 0.8125
# Epoch 12/15
# 163/163 [==============================] - 111s 679ms/step - loss: 1.5537 - accuracy: 0.8558 - val_loss: 0.3391 - val_accuracy: 0.8750
# Epoch 13/15
# 163/163 [==============================] - 111s 680ms/step - loss: 1.2970 - accuracy: 0.8531 - val_loss: 0.2886 - val_accuracy: 0.8750
# Epoch 14/15
# 163/163 [==============================] - 110s 678ms/step - loss: 1.1937 - accuracy: 0.8669 - val_loss: 0.3081 - val_accuracy: 0.8750
# Epoch 15/15
# 163/163 [==============================] - 110s 678ms/step - loss: 1.8055 - accuracy: 0.7780 - val_loss: 0.2137 - val_accuracy: 0.8750

# %% [markdown]
# ## Evaluation

# %% [markdown]
# For more detail on the code see Eval VGG16 further up in the notebook

# %%
# Create classification report
report = classification_report(true_classes, 
                               predicted_classes, 
                               target_names=class_labels)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#       NORMAL       0.40      0.39      0.39       234
#    PNEUMONIA       0.64      0.64      0.64       390
#
#     accuracy                           0.55       624
#    macro avg       0.52      0.52      0.52       624
# weighted avg       0.55      0.55      0.55       624

# %%
# Other ways of validating
test_acc = model_vgg16.evaluate(test_set)
print('The testing accuracy is :', test_acc[1]*100, '%')
# Out:
# 20/20 [==============================] - 21s 1s/step - loss: 0.5012 - binary_accuracy: 0.9135
# The testing accuracy is : 91.34615659713745 %

# %% [markdown]
# The model was able to generalize decently well. Precision on the 1 label (pneumonia) is what I optimized the model for. Given the business case, this model was only ever intended to be used as an aid to qualified doctors. To be able to pick out from a large pool of patients which ones are very likely to have pneumonia. The doctors will still have to go through each case.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# We all know even the best doctors can make mistakes. Humans can’t be right 100% of the time. But it can be hard to compare percentages between the two. There is not widespread data on doctors accuracy in pneumonia diagnosis. There are a few peer reviewed cases but they are only on a few hundred cases. So I don’t know if the average doctor correctly identifies pneumonia better or worse than the model.
# This model is still only intended to be able to aid doctors in Pneumonia screening, not replace them.
#
# There is also limited data on the error rates of doctors making it difficult to have a evaluation metric to aim for. I will include two links [link](https://pubmed.ncbi.nlm.nih.gov/18299488/) and [link](https://pubmed.ncbi.nlm.nih.gov/15759443/) to publications on this matter. But neither of them are that large of a scale of analysis and do not provide a concrete average error rate.

# %% [markdown]
# ## Future Work

# %% [markdown]
# Notes on current solution
# - **This project was completed for educational purposes only. Do not consider any of this as medical advice**
# - Pediatric patients. Adult chest x-ray results may vary
# - Small dataset
# - Relatively low iterations/testing of model architecture. I could have downsampled my data to try and get more iterations
#
#
#
#
# Future Work
# - More Data Augmentation
# - Collect a larger dataset
# - Collect more research on the error rates of doctors for diagnosing pneumonia
# - Test effectiveness on poor quality data
